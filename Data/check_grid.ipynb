# %%
import xarray as xr

# %%
a=xr.open_dataset('et_fixed.nc')

# %%
a
# Out:
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*

# %%
filename = 'et_pet_noah_daymean_0.25_degrees.nc'

file=xr.open_dataset(filename)

# %%
f2= 'et_pet_noah_daymean.nc'
f2_open = xr.open_dataset(f2)

# %%
bb=xr.concat([file,f2_open],dim='time')

# %%
del bb['RZSM']

# %%
bb = bb.drop_dims('depth')

# %%
bb.to_netcdf('et_pet_noah_daymean_0.25_degrees_with_2022-2024.nc')

# %%
f2_open
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:  (time: 15705, lon: 117, lat: 56)
# Coordinates:
#   * time     (time) datetime64[ns] 126kB 1979-01-02 1979-01-03 ... 2021-12-31
#   * lon      (lon) float64 936B -125.0 -124.5 -124.0 ... -68.0 -67.5 -67.0
#   * lat      (lat) float64 448B 25.5 26.0 26.5 27.0 27.5 ... 51.5 52.0 52.5 53.0
# Data variables:
#     EVP      (time, lat, lon) float32 412MB ...
#     PEVPR    (time, lat, lon) float32 412MB ...
#     ESR      (time, lat, lon) float32 412MB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.3.0 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Jun 20 12:25:35 2024: cdo remapbil,nldas_0.50.grd et_pe...
#     NCO:          netCDF Operators version 5.1.9 (Homepage = http://nco.sf.ne...
#     CDO:          Climate Data Operators version 2.3.0 (https://mpimet.mpg.de...

# %%
file.drop('RZSM')
# Out:
# /glade/derecho/scratch/klesinger/tmp/ipykernel_172963/919859009.py:1: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   file.drop('RZSM')
# <xarray.Dataset> Size: 396MB
# Dimensions:     (time: 1263, depth: 1, bnds: 2, lat: 112, lon: 233)
# Coordinates:
#   * time        (time) datetime64[ns] 10kB 2021-01-01 2021-01-02 ... 2024-06-16
#   * lon         (lon) float64 2kB -125.0 -124.8 -124.5 ... -67.5 -67.25 -67.0
#   * lat         (lat) float64 896B 25.12 25.38 25.62 25.88 ... 52.38 52.62 52.88
#   * depth       (depth) float64 8B 50.0
# Dimensions without coordinates: bnds
# Data variables:
#     depth_bnds  (time, depth, bnds) float64 20kB ...
#     EVP         (time, lat, lon) float32 132MB ...
#     PEVPR       (time, lat, lon) float32 132MB ...
#     ESR         (time, lat, lon) float32 132MB ...
# Attributes:
#     history:  Thu Jun 20 19:18:30 2024: ncap2 -O -s lon@units="degrees_east";...
# ...

# %%
file = file.drop('RZSM')
# Out:
# /glade/derecho/scratch/klesinger/tmp/ipykernel_172963/2596158458.py:1: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   file = file.drop('RZSM')
# <xarray.Dataset> Size: 396MB
# Dimensions:     (time: 1263, depth: 1, bnds: 2, lat: 112, lon: 233)
# Coordinates:
#   * time        (time) datetime64[ns] 10kB 2021-01-01 2021-01-02 ... 2024-06-16
#   * lon         (lon) float64 2kB -125.0 -124.8 -124.5 ... -67.5 -67.25 -67.0
#   * lat         (lat) float64 896B 25.12 25.38 25.62 25.88 ... 52.38 52.62 52.88
#   * depth       (depth) float64 8B 50.0
# Dimensions without coordinates: bnds
# Data variables:
#     depth_bnds  (time, depth, bnds) float64 20kB ...
#     EVP         (time, lat, lon) float32 132MB ...
#     PEVPR       (time, lat, lon) float32 132MB ...
#     ESR         (time, lat, lon) float32 132MB ...
# Attributes:
#     history:  Thu Jun 20 19:18:30 2024: ncap2 -O -s lon@units="degrees_east";...
# ...

# %%
# file = file.drop_dims('depth')
file.to_netcdf('test.nc')

# %%
xr.open_dataset('test.nc')
# Out:
# <xarray.Dataset> Size: 396MB
# Dimensions:  (time: 1263, lat: 112, lon: 233)
# Coordinates:
#   * time     (time) datetime64[ns] 10kB 2021-01-01 2021-01-02 ... 2024-06-16
#   * lon      (lon) float64 2kB -125.0 -124.8 -124.5 ... -67.5 -67.25 -67.0
#   * lat      (lat) float64 896B 25.12 25.38 25.62 25.88 ... 52.38 52.62 52.88
# Data variables:
#     EVP      (time, lat, lon) float32 132MB ...
#     PEVPR    (time, lat, lon) float32 132MB ...
#     ESR      (time, lat, lon) float32 132MB ...
# Attributes:
#     history:  Thu Jun 20 19:18:30 2024: ncap2 -O -s lon@units="degrees_east";...
#     NCO:      netCDF Operators version 5.1.9 (Homepage = http://nco.sf.net, C...

# %%
file.PEVPR[0,0].plot()

# %%
#OPen the ET/PET file
et = xr.open_dataset('et_pet_noah_daymean_0.25_degrees.nc')

# %%
et.time.values
# Out:
# array(['1979-01-02T00:00:00.000000000', '1979-01-03T00:00:00.000000000',
#        '1979-01-04T00:00:00.000000000', ...,
#        '2021-12-29T00:00:00.000000000', '2021-12-30T00:00:00.000000000',
#        '2021-12-31T00:00:00.000000000'], dtype='datetime64[ns]')
